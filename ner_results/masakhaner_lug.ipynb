# %%
#Upload the folder manually
# %cd /content/NLP
# Out:
# /content/NLP

# %%
# %pip install transformers datasets seqeval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 mbert.py --lang=lug
# Out:
# 2023-05-10 13:52:08.897214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found cached dataset masakhaner (/root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3)
# 100% 3/3 [00:00<00:00, 866.65it/s]
# ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-DATE', 'I-DATE']
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-77b5f6bf54543fee.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-6ce4cafbf02b5c91.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-83199246ed2324c2.arrow
# ...

# %%
# !python3 canine.py --lang=lug
# Out:
# 2023-05-10 13:53:57.141742: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found cached dataset masakhaner (/root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3)
# 100% 3/3 [00:00<00:00, 700.18it/s]
# ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-DATE', 'I-DATE']
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/lug/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-e81ebfd7de707110.arrow
# ...
