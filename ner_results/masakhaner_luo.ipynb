# %%
#Upload the folder manually
# %cd /content/NLP
# Out:
# /content/NLP

# %%
# %pip install transformers datasets seqeval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 mbert.py --lang=luo
# Out:
# 2023-05-10 11:33:09.688879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found cached dataset masakhaner (/root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3)
# 100% 3/3 [00:00<00:00, 460.71it/s]
# ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-DATE', 'I-DATE']
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-efb6da85974974b2.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-f888180337f090bf.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-cf03df80d9ff3d5f.arrow
# ...

# %%
# !python3 canine.py --lang=luo
# Out:
# 2023-05-10 11:34:12.755346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found cached dataset masakhaner (/root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3)
# 100% 3/3 [00:00<00:00, 589.92it/s]
# ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-DATE', 'I-DATE']
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Using unk_token, but it is not set yet.
# Loading cached processed dataset at /root/.cache/huggingface/datasets/masakhaner/luo/1.0.0/e61b24903076a3af7682855beebb820ec64edad0d6787b148c473694592d10b3/cache-2ab49ae9b6ecb415.arrow
# ...
